# %% [markdown]
# <a href="https://colab.research.google.com/github/lasiadhi/Prediction-of-hypoxemia-trend/blob/master/XGB_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#################################################
###### @author: Lasith Adhikari (python 3)  #####
############ Created on Nov 29, 2019 ############
# Code description: 
# Train XGB-ML models to predict hypoxemia transition

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import random
import os

random.seed(9001)
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve, auc
#from sklearn.ensemble import RandomForestClassifier
#from pygam import LogisticGAM
import xgboost as xgb
from sklearn.feature_selection import SelectFromModel

from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV, SelectKBest, f_classif
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
import time 
from sklearn.metrics import precision_recall_curve
#from sklearn.utils.fixes import signature
from sklearn.metrics import average_precision_score

pd.options.display.max_columns = 200
pd.options.display.max_rows = 200

# %%
# XGB model: 
def fitXGBClassifier(X_train, X_test, y_train, y_test):
    
    print ('Parameter tunning and feature selection for XGBClassifier: ')
    
    kbest = SelectKBest(f_classif)  # ANOVA F-value between label/feature for classification tasks (F-test captures only linear dependency)
    
    clf = xgb.XGBClassifier(random_state=0, missing=-999, reg_lambda=0)   
    
    pipeline = Pipeline([('kbest', kbest), ('xgb', clf)])
    
    # first run:
    # https://xgboost.readthedocs.io/en/latest/python/python_api.html#module-xgboost.sklearn

    n_est               = [500] # default=100
    max_depth           = [5,7]  # default=3 
    kbest_vals          = [50, 60, 70, 'all']
    learning_rate       = [0.0005,0.001]  # default=0.1
    min_child_weight    = [2,3,4] #default=1 (int) -- Minimum sum of instance weight(hessian) needed in a child)
    subsample           = [1] #default= 1 , (float) – Subsample ratio of the training instance.
    colsample_bytree    = [0.8,1] #default=1, (float) – Subsample ratio of columns when constructing each tree.
    reg_alpha           = [0.5,1,2,3,5] # default=0 (float (xgb's alpha)) – L1 regularization term on weights
    scale_pos_weight    = [1,2,5] #default=1 (float) – Balancing of positive and negative weights.
    
    '''
    # second run:
    n_est               = [500] # default=100
    max_depth           = [3,5]  # default=3 
    kbest_vals          = [50,60,70]
    learning_rate       = [0.0005,0.01]  # default=0.1
    min_child_weight    = [3] #default=1 (int) -- Minimum sum of instance weight(hessian) needed in a child)
    subsample           = [1] #default= 1 , (float) – Subsample ratio of the training instance.
    colsample_bytree    = [0.7,0.8,0.9] #default=1, (float) – Subsample ratio of columns when constructing each tree.
    '''
    
    param_grid = { 
    'kbest__k' : kbest_vals,
    'xgb__n_estimators': n_est, 
    'xgb__max_depth': max_depth,
    'xgb__learning_rate': learning_rate,
    'xgb__min_child_weight': min_child_weight,
    'xgb__subsample': subsample,
    'xgb__colsample_bytree': colsample_bytree,
    'xgb__reg_alpha': reg_alpha,
    'xgb__scale_pos_weight': scale_pos_weight
    }
    
    
    CV_rfc = GridSearchCV(pipeline, param_grid=param_grid, scoring='roc_auc', cv= 5,verbose=2,n_jobs=-1)
    CV_rfc.fit(X_train, y_train)
    print (CV_rfc.best_params_)   # print the best parameters
    
    # perform preditction using the best RF model
    predicted_y = CV_rfc.predict(X_test)
    probs       = CV_rfc.predict_proba(X_test)

    # generate some evaluation metrics
    print ('Accuracy of the RF model with selected features: ', metrics.accuracy_score(y_test, predicted_y))
    print ('ROC-AUC of the RF model with selected features: ',  metrics.roc_auc_score(y_test, probs[:,1]))   
    
    finalFeatureIndices = CV_rfc.best_estimator_.named_steps['kbest'].get_support(indices=True)
    X_important_train = X_train.iloc[:, finalFeatureIndices]
    X_important_test = X_test.iloc[:, finalFeatureIndices]
    
    
    print ("Selected features for the model: ", list(X_important_train.columns))
    return probs[:,1],X_important_train,X_important_test, CV_rfc

# %%
def plot_metrics(y_test,pred_probs_RF):
    
    # generate a df with 'tn','fp','fn','tp' for all thresholds
    df_values = pd.DataFrame(columns=['tn','fp','fn','tp'])
    thresholds = np.arange(min(pred_probs_RF),max(pred_probs_RF),0.005)
    for cut in thresholds:
        y_score_ = (pred_probs_RF>cut)*1
        row = pd.Series(list(metrics.confusion_matrix(y_test, y_score_).ravel()),index=['tn','fp','fn','tp'], name=cut)
        df_values = df_values.append(row)
    #compute specificty
    spec = df_values['tn']/(df_values['tn']+df_values['fp']+1e-100) # added 1e-100 to avoid div by zero by any case
    #compute sensitivity (recall)
    sen = df_values['tp']/(df_values['tp']+df_values['fn']+1e-100)
    #compute precesion
    pres = df_values['tp']/(df_values['tp']+df_values['fp']+1e-100)
    
    plt.gcf().set_size_inches(15, 8)
    plt.plot(thresholds, pres, 'b', label='Precision (PPV)')
    plt.plot(thresholds, sen, 'g', label = 'Recall (Sensitivity)')
    plt.plot(thresholds, spec, 'r', label = 'Specificity')
    plt.xlabel('Threshold', fontsize=15)
    plt.legend(loc='lower center', fontsize=15)
    plt.ylim([0,1])
    #plt.axvline(x=optimal_threshold, color='black',linestyle='dashed')
    plt.show()

# %%
# Define data file path to be read
FILENAME_X_test = '../Data/X_test.csv' 
FILENAME_X_train = '../Data/X_train.csv' 
FILENAME_y_test = '../Data/y_test.csv' 
FILENAME_y_train = '../Data/y_train.csv' 

X_train = pd.read_csv(FILENAME_X_train, index_col=0)
X_test = pd.read_csv(FILENAME_X_test, index_col=0)
y_train = pd.read_csv(FILENAME_y_train, index_col=0)
y_test = pd.read_csv(FILENAME_y_test, index_col=0)

# %%
# Imputations for XGB (XGB can handle missing values):
X_train = X_train.fillna(-999)
X_test = X_test.fillna(-999)

# %%
X_train.shape
# Out:
# (6767, 75)

# %%
X_test.shape
# Out:
# (2901, 75)

# %%
# code categrorical columns:
X_train['gender'] = X_train['gender'].astype('category').cat.codes
X_test['gender'] = X_test['gender'].astype('category').cat.codes

X_train['ethnicity'] = X_train['ethnicity'].astype('category').cat.codes
X_test['ethnicity'] = X_test['ethnicity'].astype('category').cat.codes

X_train['unittype'] = X_train['unittype'].astype('category').cat.codes
X_test['unittype'] = X_test['unittype'].astype('category').cat.codes

X_train['unitstaytype'] = X_train['unitstaytype'].astype('category').cat.codes
X_test['unitstaytype'] = X_test['unitstaytype'].astype('category').cat.codes

X_train['BMI_category'] = X_train['BMI_category'].astype('category').cat.codes
X_test['BMI_category'] = X_test['BMI_category'].astype('category').cat.codes

# %%
y_train.is_worse = y_train.is_worse.astype('category').cat.codes
y_test.is_worse = y_test.is_worse.astype('category').cat.codes

# %%
# test for any null values:
print('Null in X_train: ', X_train.isnull().sum(axis=0).sum())
print('Null in X_test: ', X_test.isnull().sum(axis=0).sum())

# check dump model accuracy (if we predict every test case as 1)
dump_accuracy = (y_test.sum()/len(y_test))*100
print ('Dump model accuracy (if we predict all test cases as 1):' + str(dump_accuracy))
# Out:
# Null in X_train:  0
# Null in X_test:  0
# Dump model accuracy (if we predict all test cases as 1):is_worse    22.268183
# dtype: float64

# %%
## XGB Classifier model with CV
pred_probs_XGB, iXtrain, iXtest, CV_rfc = fitXGBClassifier(X_train, X_test, y_train.is_worse, y_test.is_worse)
# Out:
# Parameter tunning and feature selection for XGBClassifier:
# Fitting 5 folds for each of 1440 candidates, totalling 7200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 616 tasks      | elapsed: 18.4min
# [Parallel(n_jobs=-1)]: Done 981 tasks      | elapsed: 26.4min
# [Parallel(n_jobs=-1)]: Done 1426 tasks      | elapsed: 37.4min
# [Parallel(n_jobs=-1)]: Done 1953 tasks      | elapsed: 50.0min
# [Parallel(n_jobs=-1)]: Done 2560 tasks      | elapsed: 64.9min
# [Parallel(n_jobs=-1)]: Done 3249 tasks      | elapsed: 84.6min
# [Parallel(n_jobs=-1)]: Done 4018 tasks      | elapsed: 107.5min
# [Parallel(n_jobs=-1)]: Done 4869 tasks      | elapsed: 133.8min
# [Parallel(n_jobs=-1)]: Done 5800 tasks      | elapsed: 164.8min
# [Parallel(n_jobs=-1)]: Done 6813 tasks      | elapsed: 198.7min
# [Parallel(n_jobs=-1)]: Done 7200 out of 7200 | elapsed: 213.6min finished
# {'kbest__k': 50, 'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.0005, 'xgb__max_depth': 5, 'xgb__min_child_weight': 2, 'xgb__n_estimators': 500, 'xgb__reg_alpha': 5, 'xgb__scale_pos_weight': 2, 'xgb__subsample': 1}
# Accuracy of the RF model with selected features:  0.7600827300930714
# ROC-AUC of the RF model with selected features:  0.5505042114873724
# Selected features for the model:  ['gender', 'unitstaytype', 'min_t_respiratoryrate', 'min_t_spo2', 'min_t_nibp_systolic', 'min_t_nibp_diastolic', 'min_t_nibp_mean', 'min_t_temperature', 'max_t_respiratoryrate', 'max_t_spo2', 'max_t_nibp_systolic', 'max_t_nibp_diastolic', 'max_t_nibp_mean', 'max_t_temperature', 'avg_t_respiratoryrate', 'avg_t_spo2', 'avg_t_nibp_systolic', 'avg_t_nibp_diastolic', 'avg_t_nibp_mean', 'avg_t_temperature', 'min_t_BUN', 'min_t_calcium', 'min_t_creatinine', 'min_t_bicarbonate', 'min_t_INR', 'min_t_sodium', 'min_t_wbc', 'min_t_RBC', 'min_t_anion gap', 'min_t_chloride', 'max_t_BUN', 'max_t_calcium', 'max_t_creatinine', 'max_t_bicarbonate', 'max_t_INR', 'max_t_sodium', 'max_t_wbc', 'max_t_RBC', 'max_t_anion gap', 'max_t_chloride', 'avg_t_BUN', 'avg_t_calcium', 'avg_t_creatinine', 'avg_t_bicarbonate', 'avg_t_INR', 'avg_t_sodium', 'avg_t_wbc', 'avg_t_RBC', 'avg_t_anion gap', 'avg_t_chloride']

# %%
# XGB - draw ROC and compute the AUC 
fpr, tpr, thresholds = roc_curve(y_test, pred_probs_XGB)
roc_auc = auc(fpr, tpr)

# plotting ROCs
plt.gcf().set_size_inches(12, 10)
plt.plot(fpr, tpr, lw=2, color='red', label='AUROC: %0.2f'% roc_auc)
plt.plot([0,1], [0,1], color='gray', lw=1, linestyle='--', label='No skill')
plt.ylabel('True positive rate', fontsize=20)
plt.xlabel('False positive rate', fontsize=20)
plt.title('ROC curve from XGBoost Classifier', fontsize=20)
plt.legend(loc='upper left', fontsize=20)
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.show()

# %%
####### feature importances from XGB ##############
forest = CV_rfc.best_estimator_.steps[1][1]
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]
print("Feature ranking:")
for f in range(len(importances)):
    print("%d. feature: %s (%f)" % (f + 1, iXtrain.columns[indices[f]], importances[indices[f]]))

# importance plot:
plt.gcf().set_size_inches(15, 6)
feat_importances = pd.Series(importances[indices], index=iXtrain.columns[indices])
feat_importances.nlargest(10)[::-1].plot(kind='barh',fontsize=15,color=cm.inferno_r(np.linspace(.4,.8, 10)))
plt.title('Top 10 important features', fontsize=15)
plt.show()
# Out:
# Feature ranking:
# 1. feature: max_t_spo2 (0.095231)
# 2. feature: avg_t_anion gap (0.055900)
# 3. feature: min_t_anion gap (0.049102)
# 4. feature: max_t_BUN (0.032346)
# 5. feature: max_t_anion gap (0.026980)
# 6. feature: avg_t_temperature (0.026627)
# 7. feature: avg_t_bicarbonate (0.025997)
# 8. feature: max_t_bicarbonate (0.024781)
# 9. feature: avg_t_calcium (0.024416)
# 10. feature: max_t_wbc (0.023987)
# 11. feature: avg_t_spo2 (0.023818)
# 12. feature: max_t_creatinine (0.023461)
# 13. feature: min_t_creatinine (0.023112)
# 14. feature: gender (0.022267)
# 15. feature: avg_t_INR (0.021612)
# 16. feature: avg_t_wbc (0.021420)
# 17. feature: min_t_respiratoryrate (0.021417)
# 18. feature: avg_t_nibp_systolic (0.020817)
# 19. feature: avg_t_BUN (0.020526)
# 20. feature: avg_t_RBC (0.019629)
# 21. feature: avg_t_chloride (0.019395)
# 22. feature: max_t_RBC (0.019295)
# 23. feature: min_t_nibp_diastolic (0.018626)
# 24. feature: min_t_calcium (0.018605)
# 25. feature: min_t_chloride (0.018238)
# 26. feature: min_t_temperature (0.016590)
# 27. feature: min_t_spo2 (0.016139)
# 28. feature: max_t_chloride (0.015599)
# 29. feature: max_t_temperature (0.015556)
# 30. feature: max_t_INR (0.015376)
# 31. feature: min_t_bicarbonate (0.015188)
# 32. feature: min_t_wbc (0.015165)
# 33. feature: min_t_nibp_mean (0.014839)
# 34. feature: max_t_nibp_systolic (0.014731)
# 35. feature: min_t_RBC (0.014333)
# 36. feature: avg_t_nibp_diastolic (0.013936)
# 37. feature: max_t_calcium (0.013817)
# 38. feature: avg_t_creatinine (0.013599)
# 39. feature: max_t_nibp_diastolic (0.012917)
# 40. feature: max_t_sodium (0.012521)
# 41. feature: avg_t_nibp_mean (0.011802)
# 42. feature: min_t_INR (0.010256)
# 43. feature: max_t_respiratoryrate (0.009962)
# 44. feature: avg_t_sodium (0.009830)
# 45. feature: min_t_BUN (0.009352)
# 46. feature: avg_t_respiratoryrate (0.009098)
# 47. feature: max_t_nibp_mean (0.008176)
# 48. feature: min_t_sodium (0.007072)
# 49. feature: min_t_nibp_systolic (0.006539)
# 50. feature: unitstaytype (0.000000)

# %%
########## Plotting Precision-recall curve ############
precision, recall, _ = precision_recall_curve(np.array(y_test), pred_probs_XGB)
#average_precision = average_precision_score(y_test, pred_probs_XGB)
pr_auc = auc(recall, precision)
plt.gcf().set_size_inches(12, 9)
plt.step(recall, precision, color='purple', alpha=1, where='post', label='AUPRC: %0.2f'% pr_auc)
plt.axhline(y = sum(y_test.is_worse)/len(y_test.is_worse), linewidth=1, color='gray', linestyle='--', label='No skill')
plt.xlabel('Recall', fontsize=20)
plt.ylabel('Precision', fontsize=20)
plt.ylim([0.0, 1.0])
plt.xlim([0.0, 1.0])
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.title('Precision-Recall curve from XGBoost Classifier',fontsize=20)
plt.legend(loc='upper right', fontsize=20)

# %%
plot_metrics(y_test,pred_probs_XGB)

# %% [markdown]
# # Second run after further tunning parameters

# %%
## XGB Classifier model with CV
pred_probs_XGB, iXtrain, iXtest, CV_rfc = fitXGBClassifier(X_train, X_test, y_train.is_worse, y_test.is_worse)
# Out:
# Parameter tunning and feature selection for XGBClassifier:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:  2.6min finished
# {'kbest__k': 50, 'xgb__colsample_bytree': 0.8, 'xgb__learning_rate': 0.0005, 'xgb__max_depth': 5, 'xgb__min_child_weight': 3, 'xgb__n_estimators': 500, 'xgb__subsample': 1}
# Accuracy of the RF model with selected features:  0.7752499138228197
# ROC-AUC of the RF model with selected features:  0.5492359599925862
# Selected features for the model:  ['gender', 'unitstaytype', 'min_t_respiratoryrate', 'min_t_spo2', 'min_t_nibp_systolic', 'min_t_nibp_diastolic', 'min_t_nibp_mean', 'min_t_temperature', 'max_t_respiratoryrate', 'max_t_spo2', 'max_t_nibp_systolic', 'max_t_nibp_diastolic', 'max_t_nibp_mean', 'max_t_temperature', 'avg_t_respiratoryrate', 'avg_t_spo2', 'avg_t_nibp_systolic', 'avg_t_nibp_diastolic', 'avg_t_nibp_mean', 'avg_t_temperature', 'min_t_BUN', 'min_t_calcium', 'min_t_creatinine', 'min_t_bicarbonate', 'min_t_INR', 'min_t_sodium', 'min_t_wbc', 'min_t_RBC', 'min_t_anion gap', 'min_t_chloride', 'max_t_BUN', 'max_t_calcium', 'max_t_creatinine', 'max_t_bicarbonate', 'max_t_INR', 'max_t_sodium', 'max_t_wbc', 'max_t_RBC', 'max_t_anion gap', 'max_t_chloride', 'avg_t_BUN', 'avg_t_calcium', 'avg_t_creatinine', 'avg_t_bicarbonate', 'avg_t_INR', 'avg_t_sodium', 'avg_t_wbc', 'avg_t_RBC', 'avg_t_anion gap', 'avg_t_chloride']

# %%
# XGB - draw ROC and compute the AUC 
fpr, tpr, thresholds = roc_curve(y_test, pred_probs_XGB)
roc_auc = auc(fpr, tpr)

# plotting ROCs
plt.gcf().set_size_inches(12, 10)
plt.plot(fpr, tpr, lw=2, color='red', label='AUROC: %0.2f'% roc_auc)
plt.plot([0,1], [0,1], color='gray', lw=1, linestyle='--', label='No skill')
plt.ylabel('True positive rate', fontsize=20)
plt.xlabel('False positive rate', fontsize=20)
plt.title('ROC curve from XGBoost Classifier', fontsize=20)
plt.legend(loc='upper left', fontsize=20)
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.show()

# %%
####### feature importances from XGB ##############
forest = CV_rfc.best_estimator_.steps[1][1]
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]
print("Feature ranking:")
for f in range(len(importances)):
    print("%d. feature: %s (%f)" % (f + 1, iXtrain.columns[indices[f]], importances[indices[f]]))

# importance plot:
plt.gcf().set_size_inches(15, 6)
feat_importances = pd.Series(importances[indices], index=iXtrain.columns[indices])
feat_importances.nlargest(10)[::-1].plot(kind='barh',fontsize=15,color=cm.inferno_r(np.linspace(.4,.8, 10)))
plt.title('Top 10 important features', fontsize=15)
plt.show()
# Out:
# Feature ranking:
# 1. feature: max_t_spo2 (0.086494)
# 2. feature: avg_t_anion gap (0.045451)
# 3. feature: min_t_anion gap (0.044675)
# 4. feature: min_t_respiratoryrate (0.031448)
# 5. feature: min_t_RBC (0.027341)
# 6. feature: max_t_anion gap (0.026428)
# 7. feature: min_t_bicarbonate (0.023651)
# 8. feature: avg_t_calcium (0.022604)
# 9. feature: avg_t_spo2 (0.022556)
# 10. feature: max_t_bicarbonate (0.022225)
# 11. feature: max_t_respiratoryrate (0.022048)
# 12. feature: max_t_RBC (0.021691)
# 13. feature: max_t_creatinine (0.021296)
# 14. feature: min_t_INR (0.020353)
# 15. feature: min_t_nibp_diastolic (0.019828)
# 16. feature: avg_t_RBC (0.019333)
# 17. feature: avg_t_nibp_systolic (0.019200)
# 18. feature: min_t_calcium (0.019017)
# 19. feature: avg_t_sodium (0.018871)
# 20. feature: max_t_wbc (0.018778)
# 21. feature: avg_t_INR (0.018634)
# 22. feature: min_t_BUN (0.018247)
# 23. feature: avg_t_bicarbonate (0.017917)
# 24. feature: max_t_BUN (0.017909)
# 25. feature: avg_t_creatinine (0.017642)
# 26. feature: avg_t_temperature (0.017525)
# 27. feature: min_t_sodium (0.017377)
# 28. feature: avg_t_wbc (0.017034)
# 29. feature: min_t_chloride (0.017005)
# 30. feature: min_t_creatinine (0.016680)
# 31. feature: avg_t_BUN (0.016637)
# 32. feature: max_t_nibp_systolic (0.016318)
# 33. feature: min_t_wbc (0.016284)
# 34. feature: max_t_chloride (0.016238)
# 35. feature: min_t_temperature (0.016151)
# 36. feature: max_t_nibp_mean (0.016067)
# 37. feature: min_t_spo2 (0.015338)
# 38. feature: max_t_INR (0.015159)
# 39. feature: max_t_nibp_diastolic (0.015092)
# 40. feature: avg_t_chloride (0.014978)
# 41. feature: min_t_nibp_systolic (0.014221)
# 42. feature: avg_t_nibp_diastolic (0.014082)
# 43. feature: max_t_calcium (0.014059)
# 44. feature: max_t_temperature (0.013791)
# 45. feature: avg_t_respiratoryrate (0.012498)
# 46. feature: avg_t_nibp_mean (0.011794)
# 47. feature: min_t_nibp_mean (0.011375)
# 48. feature: gender (0.010922)
# 49. feature: max_t_sodium (0.009740)
# 50. feature: unitstaytype (0.000000)

# %%
########## Plotting Precision-recall curve ############
precision, recall, _ = precision_recall_curve(np.array(y_test), pred_probs_XGB)
pr_auc = auc(recall, precision)
plt.gcf().set_size_inches(12, 9)
plt.step(recall, precision, color='purple', alpha=1, where='post', label='AUPRC: %0.2f'% pr_auc)
plt.axhline(y = sum(y_test.is_worse)/len(y_test.is_worse), linewidth=1, color='gray', linestyle='--', label='No skill')
plt.xlabel('Recall', fontsize=20)
plt.ylabel('Precision', fontsize=20)
plt.ylim([0.0, 1.0])
plt.xlim([0.0, 1.0])
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.title('Precision-Recall curve from XGBoost Classifier',fontsize=20)
plt.legend(loc='upper right', fontsize=20)
